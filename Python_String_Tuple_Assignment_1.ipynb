# %% [markdown]
# <a href="https://colab.research.google.com/github/MalathyParamasivam/Bike-Sharing-Network-Performance-Analysis-Using-Power-BI/blob/main/Python_String_Tuple_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
   #String Concatenation
hello="Hello"
name=input("Enter your name")
print("Hello " + name)

#concatenate string 3, "Welcome to Python programming,” to the existing string and display the output string.
name1="Welcome to Python programming"
print("Hello "+name+" Welcome to Python programming")
# Out:
# Enter your nameMalathy
# Hello Malathy
# Hello Malathy Welcome to Python programming

# %%
    #String Slicing and Indexing
stg1="Hello Malathy Welcome to Python Programming"

#Print the first character of the string
print("forward indexing access 1st char",stg1[0])

#Print the last character of the string
print(stg1[-1])

#Print the first 5 characters of the string
print(stg1[:5])

#Print the last 11 characters of the string
print(stg1[-11:])

#Print the string in reverse
print(stg1[::-1])

#Use slicing and print the word “Python” from the existing string.
print(stg1[25:31])
# Out:
# forward indexing access 1st char H
# g
# Hello
# Programming
# gnimmargorP nohtyP ot emocleW yhtalaM olleH
# Python

# %%
   #String Methods
strM ="Python beginner tutorial"

#Convert the sentence to uppercase
print(strM.upper())

#Convert the sentence to lowercase
print(strM.lower())

#Use Capitalize and return the sentence to the original input form
print(strM.capitalize())

#Count the total number of occurrences of character ‘t’ in the string
print(strM.count("t"))

#Replace all occurrences of “Python” with “Data Analytics” in the input string strM = “Python beginner tutorial.”
print(strM.replace("Python","Data Analytics"))
# Out:
# PYTHON BEGINNER TUTORIAL
# python beginner tutorial
# Python beginner tutorial
# 3
# Data Analytics beginner tutorial

# %%
  #Tuples (Creation, Modification and Access)
tup1=(10,20,30)
tup2=(40,50,60)

#Concatenate the two tuples and store it in “t_combine”
t_combine=(tup1+tup2)
print(t_combine)

#Repeat the elements of “t_combine” 3 times
print(t_combine*3)

#Access the 3rd element from “t_combine”
print(t_combine[2])

#Access the first three elements from “t_combine”
print(t_combine[:3])

#Access the last three elements from “t_combine”
print(t_combine[-3:])
# Out:
# (10, 20, 30, 40, 50, 60)
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# 30
# (10, 20, 30)
# (40, 50, 60)
